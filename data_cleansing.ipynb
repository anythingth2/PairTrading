# %%
import pandas as pd

# %%
df = pd.read_parquet('dataset/us_stock/sp500_historical.parquet')
df
# Out:
#              dateAdded                  addedSecurity removedTicker  \
# 0     October 12, 2022                Targa Resources
# 1     October 12, 2022                                         NLSN
# 2      October 3, 2022                                         CTXS
# 3      October 3, 2022                           PG&E
# 4      October 3, 2022                                          DRE
# ..                 ...                            ...           ...
# 598  December 11, 1998                 Carnival Corp.
# 599  December 11, 1998                                          SUN
# 600  December 11, 1998                      Compuware
# 601      June 17, 1997                                          USL
# 602      June 17, 1997  Countrywide Credit Industries
#
#       removedSecurity        date symbol  \
# 0                      2022-10-12   TRGP
# 1    Nielsen Holdings  2022-10-12   NLSN
# 2      Citrix Systems  2022-10-03   CTXS
# 3                      2022-10-03    PCG
# ...

# %%
df[df['symbol'] == 'FB']
# Out:
#              dateAdded addedSecurity removedTicker removedSecurity  \
# 382  December 23, 2013      Facebook
#
#            date symbol                          reason
# 382  2013-12-23     FB  Market capitalization changes.

# %%
df[df['symbol'] == 'META']
# Out:
# Empty DataFrame
# Columns: [dateAdded, addedSecurity, removedTicker, removedSecurity, date, symbol, reason]
# Index: []
